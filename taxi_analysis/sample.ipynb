# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4]
y = [5, 10, 15, 20]

# %%
plt.bar(x, y)
print(plt.xticks([3, 7, 9, 12]))
# Out:
# ([<matplotlib.axis.XTick object at 0x000001A801083050>, <matplotlib.axis.XTick object at 0x000001A87EAECB10>, <matplotlib.axis.XTick object at 0x000001A801068150>, <matplotlib.axis.XTick object at 0x000001A8010BCE50>], [Text(3, 0, '3'), Text(7, 0, '7'), Text(9, 0, '9'), Text(12, 0, '12')])
